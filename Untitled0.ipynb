# %% [markdown]
# <a href="https://colab.research.google.com/github/alimahatma/AI-Praktikum/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import re
from google.colab import drive

# %%
drive.mount('/content/drive')
data_path = '/content/drive/My Drive/GOJEK-topicmodel/'
file_names = [
    'df1.csv','df2.csv', 'df3.csv', 'df4.csv','df5.csv',
    'df6.csv','df7.csv','df8.csv','df9.csv','df10.csv',
    'df11.csv','df12.csv','df13.csv','df14.csv','df15.csv',
    'df16.csv','df17.csv','df18.csv','df19.csv','df20.csv',
    'df21.csv','df22.csv','df23.csv', 'df24.csv', 'df25.csv'
]
# Out:
# Mounted at /content/drive

# %%
dfs = []

for file_name in file_names:
  data = pd.read_csv(data_path + file_name)
  dfs.append(data)

# %%
data = pd.concat(dfs, ignore_index=True)
data.sample(10)
# Out:
#                       userName  \
# 82067   Laurencia Purwasumitra
# 24566           Cintia Leliana
# 73336            Fiki Amirudin
# 61314            KALES ADANIAR
# 34238         Noor Anggorowaty
# 221397             Fahmi Idris
# 168910             Dzikir Zami
# 73884                   Akun 1
# 199439               Aira Aira
# 20881          Saniman nugraha
#
#                                                   content     score  \
# 82067   Promonya sekarang pelit order makanan harus 30...  0.995269
# 24566   Sbg pengguna setia bertahun2 gojekgopaylater n...  0.996587
# 73336              Akun pmula semoga good job kedapan nya  0.999137
# 61314   Saran aja buat fitut goffod klo onkirnya gk bi...  0.995707
# 34238   Nggak usah ada versi hemat kalau kenyataannya ...  0.964874
# 221397                  Bagus sangat mudah cepat dan aman  0.999819
# 168910                        Susah banget upgrade goplus  0.999537
# ...

# %%
import matplotlib.pyplot as plt

doc_lengts = data['content'].str.len()

plt.figure(figsize=(8, 4))
plt.hist(doc_lengts, bins=50, color='skyblue', edgecolor='black')
plt.title('Document Length Histogram')
plt.xlabel('Length Document')
plt.ylabel('Frequency')

plt.text(1000, 300, 'Mean Length: {:.2f}'.format(doc_lengts.mean()), fontsize=12, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=1'))
plt.grid(False)
plt.savefig('histogram_doc_length.png')
plt.show()

# %%
from collections import Counter
import matplotlib.pyplot as plt

# Memilih kolom 'content' dari dataset
teks = ' '.join(data['content'].dropna())

# Memisahkan kata-kata dari teks
kata = teks.split()

# Menghitung frekuensi kata menggunakan Counter
frekuensi_kata = Counter(kata)

# Mengambil 20 kata paling umum untuk ditampilkan
kata_umum = [kata for kata, _ in frekuensi_kata.most_common(20)]
frekuensi_umum = [frekuensi_kata[kata] for kata in kata_umum]

# Warna standar dari palet 'tab10'
colors = plt.cm.tab10(range(len(kata_umum)))

# Plot grafik frekuensi kata
plt.figure(figsize=(8, 4))
bars = plt.bar(kata_umum, frekuensi_umum, color=colors)
plt.xlabel('Word in Documents')
plt.ylabel('Frequency')
plt.title('Word Frequency in Documents')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Menambahkan label nilai di atas setiap bar
for bar, nilai in zip(bars, frekuensi_umum):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 5, str(nilai), ha='center', color='black', fontsize=6)

plt.savefig('number_of_word.png')
plt.show()

# %%
# !pip install Sastrawi

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   userName    45000 non-null  object
#  1   content     44999 non-null  object
#  2   score       45000 non-null  float64
#  3   at          45000 non-null  object
#  4   appVersion  45000 non-null  object
#  5   text        45000 non-null  object
#  6   label       45000 non-null  object
#  7   sentiment   45000 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 2.7+ MB

# %%
import re
import nltk
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# Download resources jika belum diunduh
nltk.download('stopwords')
nltk.download('punkt')

# Inisialisasi stopword Bahasa Indonesia
stop_words = set(stopwords.words('indonesian'))

factory = StemmerFactory()
stemmer = factory.create_stemmer()

def clean_tweet(tweet):
    # Pastikan tweet berupa string
    if type(tweet) != str:
        return ""

    # Mengubah teks menjadi huruf kecil
    tweet = tweet.lower()

    # Menghapus username, karakter khusus, dan URL
    tweet = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\s+)", " ", tweet)

    # Tokenisasi
    words = nltk.word_tokenize(tweet)

    # Menghapus stopwords Bahasa Indonesia
    words = [word for word in words if word not in stop_words]

     # Stemming
    stemmed_words = [stemmer.stem(word) for word in words]

    data_clean = ' '.join(stemmed_words)

    return data_clean
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
data['clean_content'] = data['content'].apply(clean_tweet)

# %%
data.sample(10)
# Out:
#                         userName  \
# 43953               Dian Adiarti
# 6545   Ronaldpanjaitan Panjaitan
# 42061                   dio keke
# 16984                 Annisa Haq
# 4116          Dodiet Ferdiansyah
# 21779                 Kipli Pali
# 13050                 Nopri Andi
# 26005                  Aris Kopo
# 37385                 Much Tosin
# 26639                  Nisa Fath
#
#                                                  content     score  \
# 43953                       Pelatihan tidak mengecewakan  0.998779
# 6545   Selalu memuaskan selama saya pesan gojek untuk...  0.999708
# 42061                                            Selesai  0.586501
# 16984  Sudah sy update aplikasi gojeknya knp sy gak b...  0.997000
# 4116                                  Mantab apk nya gan  0.999640
# 21779                         Gofood kemahalan ongkirnya  0.999651
# 13050                                                 Ok  0.998910
# ...

# %%
data.to_csv('datasets5.csv', index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

X = data['clean_content']
y = data['label']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Normalisasi data fitur menggunakan TF-IDF Vectorizer
vectorizer = TfidfVectorizer()
X_train_normalized = vectorizer.fit_transform(X_train)
X_test_normalized = vectorizer.transform(X_test)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# Inisialisasi klasifikasi
classifiers = {
    "Decision Tree": DecisionTreeClassifier(),
    "Multilayer Perceptron": MLPClassifier(),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "Naive Bayes": MultinomialNB()  # Tambahkan model Naive Bayes
}

results = {}

# Training dan evaluasi masing-masing model dengan Grid Search CV
for clf_name, clf in classifiers.items():
    pipeline = make_pipeline(StandardScaler(with_mean=False), clf)
    param_grid = {}  # Definisikan parameter grid sesuai kebutuhan
    grid_search = GridSearchCV(pipeline, param_grid, cv=5)  # Cross-validation dengan 5 fold
    grid_search.fit(X_train_normalized, y_train)
    y_pred = grid_search.predict(X_test_normalized)
    accuracy = accuracy_score(y_test, y_pred)
    report = classification_report(y_test, y_pred, output_dict=True)
    results[clf_name] = {"accuracy": accuracy, "classification_report": report}

# # Menampilkan hasil perbandingan
# for clf_name, result in results.items():
#     print(f"Classifier: {clf_name}")
#     print(f"Accuracy: {result['accuracy']}")
#     print("Classification Report:")

#     print(result['classification_report'])
    #  print("\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:693: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:693: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-5b953ce4b2f5> in <cell line: 27>()
#      29     param_grid = {}  # Definisikan parameter grid sesuai kebutuhan
#      30     grid_search = GridSearchCV(pipeline, param_grid, cv=5)  # Cross-validation dengan 5 fold
# ---> 31     grid_search.fit(X_train_normalized, y_train)
#      32     y_pred = grid_search.predict(X_test_normalized)
#      33     accuracy = accuracy_score(y_test, y_pred)
#
# ...

# %%
import pandas as pd

# Membuat DataFrame dari hasil uji coba
results_df = pd.DataFrame(results).T

# Menyiapkan kolom-kolom untuk akurasi, precision, recall, f1-score, dan support
results_df['accuracy'] = results_df['classification_report'].apply(lambda x: x['accuracy'])
results_df['precision'] = results_df['classification_report'].apply(lambda x: x['macro avg']['precision'])
results_df['recall'] = results_df['classification_report'].apply(lambda x: x['macro avg']['recall'])
results_df['f1-score'] = results_df['classification_report'].apply(lambda x: x['macro avg']['f1-score'])
results_df['support'] = results_df['classification_report'].apply(lambda x: x['macro avg']['support'])

# Menampilkan tabel hasil uji coba dengan kolom tambahan
print(results_df[['accuracy', 'precision', 'recall', 'f1-score', 'support']])
